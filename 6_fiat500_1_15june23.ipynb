# %% [markdown]
# # GRAPHS________15/thursday
# #fiat 500 data

# %%
import pandas as pd

# %%
#by using vehicle data ,i can do analysis.......................
data=pd.read_csv("/home/placement/Desktop/saimohan data/csv files/fiat500.csv")

# %%
data
# Out:
#         ID   model  engine_power  age_in_days      km  previous_owners  \
# 0        1  lounge            51          882   25000                1
# 1        2     pop            51         1186   32500                1
# 2        3   sport            74         4658  142228                1
# 3        4  lounge            51         2739  160000                1
# 4        5     pop            73         3074  106880                1
# ...    ...     ...           ...          ...     ...              ...
# 1533  1534   sport            51         3712  115280                1
# 1534  1535  lounge            74         3835  112000                1
# 1535  1536     pop            51         2223   60457                1
# 1536  1537  lounge            51         2557   80750                1
# 1537  1538     pop            51         1766   54276                1
#
#             lat        lon  price
# 0     44.907242   8.611560   8900
# 1     45.666359  12.241890   8800
# ...

# %%
data.plot()
# Out:
# <Axes: >

# %%
#i want which command is float or int we use
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1538 entries, 0 to 1537
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               1538 non-null   int64
#  1   model            1538 non-null   object
#  2   engine_power     1538 non-null   int64
#  3   age_in_days      1538 non-null   int64
#  4   km               1538 non-null   int64
#  5   previous_owners  1538 non-null   int64
#  6   lat              1538 non-null   float64
#  7   lon              1538 non-null   float64
#  8   price            1538 non-null   int64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 108.3+ KB

# %%
data1=data.loc[data.km<= 50000]

# %%
data1
# Out:
#         ID   model  engine_power  age_in_days     km  previous_owners  \
# 0        1  lounge            51          882  25000                1
# 1        2     pop            51         1186  32500                1
# 6        7  lounge            51          731  11600                1
# 7        8  lounge            51         1521  49076                1
# 10      11     pop            51          790  43286                1
# ...    ...     ...           ...          ...    ...              ...
# 1525  1526  lounge            51          790  41870                1
# 1526  1527  lounge            51         1705  23600                1
# 1527  1528     pop            51          517   3000                1
# 1529  1530  lounge            51          731  22551                1
# 1530  1531  lounge            51          670  29000                1
#
#             lat       lon  price
# 0     44.907242   8.61156   8900
# 1     45.666359  12.24189   8800
# ...

# %%
data1.plot()
# Out:
# <Axes: >

# %%
data2=data.groupby(['model']).count()

data2
# Out:
#           ID  engine_power  age_in_days    km  previous_owners   lat   lon  \
# model
# lounge  1094          1094         1094  1094             1094  1094  1094
# pop      358           358          358   358              358   358   358
# sport     86            86           86    86               86    86    86
#
#         price
# model
# lounge   1094
# pop       358
# sport      86

# %%
data2=data.groupby(['model']).count()

data2
# Out:
#           ID  engine_power  age_in_days    km  previous_owners   lat   lon  \
# model
# lounge  1094          1094         1094  1094             1094  1094  1094
# pop      358           358          358   358              358   358   358
# sport     86            86           86    86               86    86    86
#
#         price
# model
# lounge   1094
# pop       358
# sport      86

# %%
#we can modify the column name with new name
data3=data1.rename(columns={'model':'model_name'})
list(data3)
# Out:
# ['ID',
#  'model_name',
#  'engine_power',
#  'age_in_days',
#  'km',
#  'previous_owners',
#  'lat',
#  'lon',
#  'price']

# %%
data3
# we can observe below table ,column name changed as (model) to (model_name)
# Out:
#         ID model_name  engine_power  age_in_days     km  previous_owners  \
# 0        1     lounge            51          882  25000                1
# 1        2        pop            51         1186  32500                1
# 6        7     lounge            51          731  11600                1
# 7        8     lounge            51         1521  49076                1
# 10      11        pop            51          790  43286                1
# ...    ...        ...           ...          ...    ...              ...
# 1525  1526     lounge            51          790  41870                1
# 1526  1527     lounge            51         1705  23600                1
# 1527  1528        pop            51          517   3000                1
# 1529  1530     lounge            51          731  22551                1
# 1530  1531     lounge            51          670  29000                1
#
#             lat       lon  price
# 0     44.907242   8.61156   8900
# ...

# %%
data['model'].unique()
# Out:
# array(['lounge', 'pop', 'sport'], dtype=object)

# %%
#piecharts
'''we are using for percentage of share for any company'''

# %%
data.shape

# %%
#we can remove the columb
data4=data3.drop(['model_name'],axis=1)
data4

# %%
#correletion b/w the data
cor=data4.corr()
cor

# %%
#MEANINGFULL CORRELETION ABOVE DATA

#cor1=data3(['km','price'])
#cor1

# %%
data['model']=data['model'].map({'lounge':1,'pop':2,'sport':3})

# %%
data
